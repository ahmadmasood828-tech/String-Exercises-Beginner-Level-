# %% [markdown]
# # 1. Create a string "Python Programming" and print only "Programming" using slicing.

# %%
text = "Python Programming"

print(text[7:])
# Out:
# Programming

# %% [markdown]
# # 2. From "Hello World", print "World" using negative indexing.

# %%
text = "Hello World"

print(text[-5:])
# Out:
# World

# %% [markdown]
# # Given text = "Developer", print every second character using slicing.

# %%
text = "Developer"
print(text[::2])
# Out:
# Dvlpr

# %% [markdown]
# # 4. Reverse the string "OpenAI" using slicing.

# %%
text = "OpenAI"
print(text[::-1])
# Out:
# IAnepO

# %% [markdown]
# # 5. Extract "gram" from "Programming" using slicing.

# %%
text = "Programming"
print(text[3:7])
# Out:
# gram

# %% [markdown]
# # Given text = "Data Science", replace "Science" with "Analysis".

# %%
text = "Data Science"
print(text.replace("Science", "Analysis"))
# Out:
# Data Analysis

# %% [markdown]
# # Convert "python is fun" into uppercase and store it in a new variable.

# %%
text = "python is fun"

new_text = text.upper()

print(new_text)
# Out:
# PYTHON IS FUN

# %% [markdown]
# # Convert "WELCOME" into lowercase and print it.

# %%
text = "WELCOME"
print(text.lower())
# Out:
# welcome

# %% [markdown]
# # 9. Count how many times "e" appears in "experience"

# %%
text = "experience"
print(text.count("e"))
# Out:
# 4

# %% [markdown]
# # 10. Find the index of "a" in "banana" (first occurrence)

# %%
text = "banana"
print(text.index("a"))
# Out:
# 1

# %% [markdown]
# # 11. Remove leading and trailing spaces from " Hello Python ".

# %%
text = "Hell Python "

print(text.strip())
# Out:
# Hell Python

# %% [markdown]
# # 12. Replace all spaces in "I love coding" with _.

# %%
text = "I love coding"
print(text.replace(" ", "_"))
# Out:
# I_love_coding

# %% [markdown]
# # 13. From "ABCDEFGHIJ", extract "CDEFG" using slicing.

# %%
text = "ABCDEFGHIJ"

print(text[2:7])
# Out:
# CDEFG

# %% [markdown]
# # 14. Print the last 4 characters of "JavaScript".

# %%
text = "JavaScript"

print(text[-4:])
# Out:
# ript

# %% [markdown]
# # 15. From "FullStack", print characters from index 1 to second last.

# %%
text = "FullStack"
print(text[1:-1])
# Out:
# ullStac

# %% [markdown]
# # 16. Create variables: name = "Aman", age = 25. Use an f-string to print "My name is Aman and I am 25 years old".

# %%
name = "Aman"
age = 25
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Aman and I am 25 years old.

# %% [markdown]
# # 17. Create variables: apples = 3, bananas = 2. Use .format() to print "I have 3 apples and 2 bananas".

# %%
apples = 3
bananas = 2

print("I have {} apples and {} bananas".format(apples, bananas))
# Out:
# I have 3 apples and 2 bananas

# %% [markdown]
# # 18. Print the string: This is "Python" using escape characters.

# %%
print("This is \"Python\"")
# Out:
# This is "Python"

# %% [markdown]
# # 19. Create a multi-line string for an address using triple quotes.

# %%
address = """Name : Masood Ahmad
City : New Delhi
Country : India
Pin Code : 110025"""

print(address)
# Out:
# Name : Masood Ahmad
# City : New Delhi
# Country : India
# Pin Code : 110025

# %% [markdown]
# # 20.Print a string with a new line using \n.

# %%
Address = "My name is Ahmad \n I am from UP"
print(Address)
# Out:
# My name is Ahmad
#  I am from UP

# %% [markdown]
# # 21. Convert "hello world" into "Hello World" using string methods.

# %%
text = "hello world"
print(text.title())
# Out:
# Hello World

# %% [markdown]
# # 22. Swap the case of "PyThOn".

# %%
text = "PyThOn"
print(text.swapcase())
# Out:
# pYtHoN

# %% [markdown]
# # 23. Find the length of "Artificial Intelligence".

# %%
text = "Artificial Intelligence"
print(len(text))
# Out:
# 23

# %% [markdown]
# # 24. From "MachineLearning", extract "Learning" using slicing

# %%
text = "MachineLearning"

print(text[7:])
# Out:
# Learning

# %% [markdown]
# # 25. Print characters from index 2 to 8 in "DataAnalytics".

# %%
text = "DataAnalytics"
print(text[2:9])
# Out:
# taAnal

# %% [markdown]
# # 26. Replace "2024" with "2025" in "Happy New Year 2024"

# %%
text = "Happy New Year 2024"
print(text.replace("2024", "2025"))
# Out:
# Happy New Year 2025

# %% [markdown]
# # 27. Find the position of "@" in "user@gmail.com".

# %%
text = "user@gmail.com"
print(text.find("@"))

text = "user@gmail.com"

print(text.index("@"))
# Out:
# 4
# 4

# %% [markdown]
# # 28. Convert "123" (string) into an integer.

# %%
text = "123"

number = int(text)

print(number)
print(type(number))

text = "123"
number = int(text)
print(number)
print(type(number))
# Out:
# 123
# <class 'int'>
# 123
# <class 'int'>
